# %%
import torch
def shift_tokens_right(input_ids: torch.Tensor, pad_token_id: int, decoder_start_token_id: int):
    """
    Shift input ids one token to the right.
    """
    shifted_input_ids = input_ids.new_zeros(input_ids.shape)
    shifted_input_ids[:, 1:] = input_ids[:, :-1].clone()
    shifted_input_ids[:, 0] = decoder_start_token_id

    if pad_token_id is None:
        raise ValueError("self.model.config.pad_token_id has to be defined.")
    # replace possible -100 values in labels by `pad_token_id`
    shifted_input_ids.masked_fill_(shifted_input_ids == -100, pad_token_id)

    return shifted_input_ids

# %%
from transformers import AutoTokenizer, BartForConditionalGeneration
import torch

tokenizer = AutoTokenizer.from_pretrained("facebook/bart-base", forced_bos_token_id=0)
model = BartForConditionalGeneration.from_pretrained("facebook/bart-base")

TXT = "I wish that <mask> was true."
input_ids = tokenizer([TXT], return_tensors="pt")["input_ids"]
logits = model(input_ids).logits
positions = (input_ids.squeeze() == tokenizer.mask_token_id).nonzero()
mask_pos = [mask.item() for mask in positions]

with torch.no_grad():
    output = model(input_ids)

last_hidden_state = output[0].squeeze()

for mask_ind in mask_pos:
    mask_hidden_state = last_hidden_state[mask_ind]
    tok_ids = torch.topk(mask_hidden_state, k=10, dim=0)[1]
    print(tok_ids[0])

    words = [tokenizer.decode(i.item()).strip() for i in tok_ids]

    TXT = TXT.replace("<mask>", words[0], 1)
    print(TXT, words)

print(last_hidden_state.shape)
print(model.model.encoder.embed_tokens(input_ids).shape)
# Out:
# tensor(24)
# I wish that it was true. ['it', 'was', 'the', 'story', 'this', 'all', 'that', 'my', 'I', 'what']
# torch.Size([9, 50265])
# torch.Size([1, 9, 768])

# %%
TXT = "I really like <mask> cupcakes"
input_ids = tokenizer([TXT], return_tensors="pt")["input_ids"]
positions = (input_ids.squeeze() == tokenizer.mask_token_id).nonzero()
mask_pos = [mask.item() for mask in positions]

state = model.model.encoder(input_ids)
#state.last_hidden_state += torch.randn_like(state.last_hidden_state) * .1
outputs = model.model.decoder(input_ids = shift_tokens_right(input_ids, model.model.config.pad_token_id, model.model.config.decoder_start_token_id), encoder_hidden_states=state[0])
lm_logits = model.lm_head(outputs[0])
lm_logits = lm_logits + model.final_logits_bias.to(lm_logits.device)
tokenizer.decode(lm_logits[0][mask_pos[0]].argmax())
# Out:
# ' these'

# %%
tokenizer.decode(model.lm_head(model.model.decoder(inputs_embeds=model.model.encoder(inputs_embeds=outputs[0])[0])[0])[0].argmax(dim=-1))
# Out:
# 'voisisisvovovois'

# %%
target_distance = torch.tensor(.1)
threshold = .01
distance = target_distance + 1
passed = False
iterations_passed = 0
iterations_max = 100

distance_metric = torch.nn.CosineSimilarity(dim=1, eps=1e-08)

# %%
torch.autograd.set_detect_anomaly(True)

embedding2 = model.model.encoder(input_ids).last_hidden_state

embedding = torch.tensor(embedding2, requires_grad=True)
optimizer = torch.optim.Adam([embedding], lr=.005)

outputs = model.model.decoder(input_ids = shift_tokens_right(input_ids, model.model.config.pad_token_id, model.model.config.decoder_start_token_id), encoder_hidden_states=embedding)
base = torch.tensor(model.model.encoder(inputs_embeds=outputs.last_hidden_state).last_hidden_state, requires_grad=True)

lm_logits = model.lm_head(outputs[0])
prior_token = tokenizer.decode(lm_logits[0][mask_pos[0]].argmax())
passed = False
counter = 0
distance = threshold + 1


while (distance > threshold or not passed) or tokenizer.decode(lm_logits[0][mask_pos[0]].argmax()) == prior_token:
    if distance < threshold and counter > 10:
        passed = True

    if passed == True:
        iterations_passed += 1
    
    decoded_output = model.model.decoder(input_ids = shift_tokens_right(input_ids, model.model.config.pad_token_id, model.model.config.decoder_start_token_id), encoder_hidden_states=embedding)
    encoded_output = model.model.encoder(inputs_embeds=decoded_output.last_hidden_state)
    lm_logits = model.lm_head(decoded_output.last_hidden_state)

    if passed:
        distance = torch.abs(target_distance - torch.mean(torch.abs(distance_metric(base, encoded_output.last_hidden_state)))) * max(0, (iterations_max - iterations_passed) / iterations_max) - torch.mean(distance_metric(base, encoded_output.last_hidden_state)) * (iterations_passed / iterations_max)
    else:
        distance = torch.abs(target_distance - torch.mean(torch.abs(distance_metric(base, encoded_output.last_hidden_state))))

    loss = distance + torch.sum(torch.abs(base - embedding)) * .00001

    print(distance, passed, tokenizer.decode(lm_logits[0][mask_pos[0]].argmax()))
    loss.backward(retain_graph=True)
    optimizer.step()
    optimizer.zero_grad()

    counter += 1
# Out:
# /tmp/ipykernel_468094/149778209.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   embedding = torch.tensor(embedding2, requires_grad=True)
# /tmp/ipykernel_468094/149778209.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   base = torch.tensor(model.model.encoder(inputs_embeds=outputs.last_hidden_state).last_hidden_state, requires_grad=True)
# tensor(0.9000, grad_fn=<AbsBackward0>) False  these
# tensor(0.8919, grad_fn=<AbsBackward0>) False  these
# tensor(0.8046, grad_fn=<AbsBackward0>) False  these
# tensor(0.7802, grad_fn=<AbsBackward0>) False  these
# tensor(0.7736, grad_fn=<AbsBackward0>) False  these
# tensor(0.7519, grad_fn=<AbsBackward0>) False  these
# tensor(0.7521, grad_fn=<AbsBackward0>) False  these
# tensor(0.7352, grad_fn=<AbsBackward0>) False  these
# tensor(0.7231, grad_fn=<AbsBackward0>) False  these
# tensor(0.7036, grad_fn=<AbsBackward0>) False  these
# tensor(0.6888, grad_fn=<AbsBackward0>) False  these
# tensor(0.6503, grad_fn=<AbsBackward0>) False  these
# tensor(0.6144, grad_fn=<AbsBackward0>) False  these
# tensor(0.5837, grad_fn=<AbsBackward0>) False  these
# tensor(0.5729, grad_fn=<AbsBackward0>) False  these
# tensor(0.5530, grad_fn=<AbsBackward0>) False  these
# tensor(0.5281, grad_fn=<AbsBackward0>) False  these
# tensor(0.5095, grad_fn=<AbsBackward0>) False  these
# tensor(0.4879, grad_fn=<AbsBackward0>) False  these
# tensor(0.4715, grad_fn=<AbsBackward0>) False  these
# tensor(0.4594, grad_fn=<AbsBackward0>) False  these
# tensor(0.4509, grad_fn=<AbsBackward0>) False  these
# tensor(0.4380, grad_fn=<AbsBackward0>) False  these
# tensor(0.4223, grad_fn=<AbsBackward0>) False  these
# tensor(0.4136, grad_fn=<AbsBackward0>) False  these
# tensor(0.4046, grad_fn=<AbsBackward0>) False  these
# tensor(0.3865, grad_fn=<AbsBackward0>) False  these
# tensor(0.3728, grad_fn=<AbsBackward0>) False  these
# tensor(0.3685, grad_fn=<AbsBackward0>) False  these
# tensor(0.3624, grad_fn=<AbsBackward0>) False  these
# tensor(0.3553, grad_fn=<AbsBackward0>) False  these
# tensor(0.3491, grad_fn=<AbsBackward0>) False  these
# tensor(0.3408, grad_fn=<AbsBackward0>) False  these
# tensor(0.3356, grad_fn=<AbsBackward0>) False  these
# tensor(0.3283, grad_fn=<AbsBackward0>) False  these
# tensor(0.3223, grad_fn=<AbsBackward0>) False  these
# tensor(0.3151, grad_fn=<AbsBackward0>) False  these
# tensor(0.3122, grad_fn=<AbsBackward0>) False  these
# tensor(0.3085, grad_fn=<AbsBackward0>) False  these
# tensor(0.3011, grad_fn=<AbsBackward0>) False  these
# tensor(0.2949, grad_fn=<AbsBackward0>) False  these
# tensor(0.2934, grad_fn=<AbsBackward0>) False  these
# tensor(0.2876, grad_fn=<AbsBackward0>) False  these
# tensor(0.2826, grad_fn=<AbsBackward0>) False  these
# tensor(0.2778, grad_fn=<AbsBackward0>) False  these
# tensor(0.2761, grad_fn=<AbsBackward0>) False  these
# tensor(0.2727, grad_fn=<AbsBackward0>) False  these
# tensor(0.2670, grad_fn=<AbsBackward0>) False  these
# tensor(0.2653, grad_fn=<AbsBackward0>) False  these
# tensor(0.2633, grad_fn=<AbsBackward0>) False  these
# tensor(0.2592, grad_fn=<AbsBackward0>) False  these
# tensor(0.2575, grad_fn=<AbsBackward0>) False  these
# tensor(0.2560, grad_fn=<AbsBackward0>) False  these
# tensor(0.2529, grad_fn=<AbsBackward0>) False  these
# tensor(0.2439, grad_fn=<AbsBackward0>) False  these
# tensor(0.2460, grad_fn=<AbsBackward0>) False  these
# tensor(0.2383, grad_fn=<AbsBackward0>) False  these
# tensor(0.2433, grad_fn=<AbsBackward0>) False  these
# tensor(0.2375, grad_fn=<AbsBackward0>) False  these
# tensor(0.2316, grad_fn=<AbsBackward0>) False  these
# tensor(0.2323, grad_fn=<AbsBackward0>) False  these
# tensor(0.2258, grad_fn=<AbsBackward0>) False  these
# tensor(0.2243, grad_fn=<AbsBackward0>) False  these
# tensor(0.2225, grad_fn=<AbsBackward0>) False  these
# tensor(0.2179, grad_fn=<AbsBackward0>) False  these
# tensor(0.2168, grad_fn=<AbsBackward0>) False  these
# tensor(0.2142, grad_fn=<AbsBackward0>) False  these
# tensor(0.2100, grad_fn=<AbsBackward0>) False  these
# tensor(0.2067, grad_fn=<AbsBackward0>) False  these
# tensor(0.2061, grad_fn=<AbsBackward0>) False  these
# tensor(0.2046, grad_fn=<AbsBackward0>) False  these
# tensor(0.1992, grad_fn=<AbsBackward0>) False  these
# tensor(0.2018, grad_fn=<AbsBackward0>) False  these
# tensor(0.2090, grad_fn=<AbsBackward0>) False  these
# tensor(0.2015, grad_fn=<AbsBackward0>) False  these
# tensor(0.2039, grad_fn=<AbsBackward0>) False  these
# tensor(0.1936, grad_fn=<AbsBackward0>) False  these
# tensor(0.2001, grad_fn=<AbsBackward0>) False  these
# tensor(0.1925, grad_fn=<AbsBackward0>) False  these
# tensor(0.1936, grad_fn=<AbsBackward0>) False  these
# tensor(0.1890, grad_fn=<AbsBackward0>) False  these
# tensor(0.1864, grad_fn=<AbsBackward0>) False  these
# tensor(0.1865, grad_fn=<AbsBackward0>) False  these
# tensor(0.1819, grad_fn=<AbsBackward0>) False  these
# tensor(0.1803, grad_fn=<AbsBackward0>) False  these
# tensor(0.1778, grad_fn=<AbsBackward0>) False  these
# tensor(0.1770, grad_fn=<AbsBackward0>) False  these
# tensor(0.1750, grad_fn=<AbsBackward0>) False  these
# tensor(0.1727, grad_fn=<AbsBackward0>) False  these
# tensor(0.1709, grad_fn=<AbsBackward0>) False  these
# tensor(0.1709, grad_fn=<AbsBackward0>) False  these
# tensor(0.1676, grad_fn=<AbsBackward0>) False  these
# tensor(0.1653, grad_fn=<AbsBackward0>) False  these
# tensor(0.1649, grad_fn=<AbsBackward0>) False  these
# tensor(0.1627, grad_fn=<AbsBackward0>) False  these
# tensor(0.1613, grad_fn=<AbsBackward0>) False  these
# tensor(0.1600, grad_fn=<AbsBackward0>) False  these
# tensor(0.1578, grad_fn=<AbsBackward0>) False  these
# tensor(0.1555, grad_fn=<AbsBackward0>) False  these
# tensor(0.1560, grad_fn=<AbsBackward0>) False  these
# tensor(0.1540, grad_fn=<AbsBackward0>) False  these
# tensor(0.1535, grad_fn=<AbsBackward0>) False  these
# tensor(0.1502, grad_fn=<AbsBackward0>) False  these
# tensor(0.1525, grad_fn=<AbsBackward0>) False  these
# tensor(0.1512, grad_fn=<AbsBackward0>) False  these
# tensor(0.1511, grad_fn=<AbsBackward0>) False  these
# tensor(0.1470, grad_fn=<AbsBackward0>) False  these
# tensor(0.1449, grad_fn=<AbsBackward0>) False  these
# tensor(0.1435, grad_fn=<AbsBackward0>) False  these
# tensor(0.1448, grad_fn=<AbsBackward0>) False  these
# tensor(0.1432, grad_fn=<AbsBackward0>) False  these
# tensor(0.1397, grad_fn=<AbsBackward0>) False  these
# tensor(0.1436, grad_fn=<AbsBackward0>) False  these
# tensor(0.1393, grad_fn=<AbsBackward0>) False  these
# tensor(0.1384, grad_fn=<AbsBackward0>) False  these
# tensor(0.1383, grad_fn=<AbsBackward0>) False  these
# tensor(0.1343, grad_fn=<AbsBackward0>) False  these
# tensor(0.1353, grad_fn=<AbsBackward0>) False  these
# tensor(0.1325, grad_fn=<AbsBackward0>) False  these
# tensor(0.1363, grad_fn=<AbsBackward0>) False  these
# tensor(0.1337, grad_fn=<AbsBackward0>) False  these
# tensor(0.1306, grad_fn=<AbsBackward0>) False  these
# tensor(0.1298, grad_fn=<AbsBackward0>) False  these
# tensor(0.1293, grad_fn=<AbsBackward0>) False  these
# tensor(0.1270, grad_fn=<AbsBackward0>) False  these
# tensor(0.1288, grad_fn=<AbsBackward0>) False  these
# tensor(0.1322, grad_fn=<AbsBackward0>) False  these
# tensor(0.1308, grad_fn=<AbsBackward0>) False  these
# tensor(0.1246, grad_fn=<AbsBackward0>) False  these
# tensor(0.1239, grad_fn=<AbsBackward0>) False  these
# tensor(0.1224, grad_fn=<AbsBackward0>) False  these
# tensor(0.1231, grad_fn=<AbsBackward0>) False  these
# tensor(0.1207, grad_fn=<AbsBackward0>) False  these
# tensor(0.1214, grad_fn=<AbsBackward0>) False  these
# tensor(0.1236, grad_fn=<AbsBackward0>) False  these
# tensor(0.1217, grad_fn=<AbsBackward0>) False  these
# tensor(0.1199, grad_fn=<AbsBackward0>) False  these
# tensor(0.1188, grad_fn=<AbsBackward0>) False  these
# tensor(0.1210, grad_fn=<AbsBackward0>) False  these
# tensor(0.1238, grad_fn=<AbsBackward0>) False  these
# tensor(0.1165, grad_fn=<AbsBackward0>) False  these
# tensor(0.1206, grad_fn=<AbsBackward0>) False  these
# tensor(0.1159, grad_fn=<AbsBackward0>) False  these
# tensor(0.1185, grad_fn=<AbsBackward0>) False  these
# tensor(0.1200, grad_fn=<AbsBackward0>) False  these
# tensor(0.1151, grad_fn=<AbsBackward0>) False  these
# tensor(0.1149, grad_fn=<AbsBackward0>) False  my
# tensor(0.1154, grad_fn=<AbsBackward0>) False  my
# tensor(0.1195, grad_fn=<AbsBackward0>) False  my
# tensor(0.1141, grad_fn=<AbsBackward0>) False  my
# tensor(0.1182, grad_fn=<AbsBackward0>) False  my
# tensor(0.1165, grad_fn=<AbsBackward0>) False  my
# tensor(0.1144, grad_fn=<AbsBackward0>) False  my
# tensor(0.1127, grad_fn=<AbsBackward0>) False  my
# tensor(0.1124, grad_fn=<AbsBackward0>) False  my
# tensor(0.1138, grad_fn=<AbsBackward0>) False  my
# tensor(0.1124, grad_fn=<AbsBackward0>) False  my
# tensor(0.1111, grad_fn=<AbsBackward0>) False  my
# tensor(0.1132, grad_fn=<AbsBackward0>) False  my
# tensor(0.1102, grad_fn=<AbsBackward0>) False  my
# tensor(0.1072, grad_fn=<AbsBackward0>) False  my
# tensor(0.1088, grad_fn=<AbsBackward0>) False  my
# tensor(0.1100, grad_fn=<AbsBackward0>) False  my
# tensor(0.1136, grad_fn=<AbsBackward0>) False  my
# tensor(0.1081, grad_fn=<AbsBackward0>) False  my
# tensor(0.1093, grad_fn=<AbsBackward0>) False  my
# tensor(0.1100, grad_fn=<AbsBackward0>) False  my
# tensor(0.1057, grad_fn=<AbsBackward0>) False  my
# tensor(0.1058, grad_fn=<AbsBackward0>) False  my
# tensor(0.1052, grad_fn=<AbsBackward0>) False  my
# tensor(0.1041, grad_fn=<AbsBackward0>) False  my
# tensor(0.1055, grad_fn=<AbsBackward0>) False  my
# tensor(0.1066, grad_fn=<AbsBackward0>) False  my
# tensor(0.1111, grad_fn=<AbsBackward0>) False  my
# tensor(0.1040, grad_fn=<AbsBackward0>) False  my
# tensor(0.1100, grad_fn=<AbsBackward0>) False  my
# tensor(0.1043, grad_fn=<AbsBackward0>) False  my
# tensor(0.1029, grad_fn=<AbsBackward0>) False  my
# tensor(0.1060, grad_fn=<AbsBackward0>) False  my
# tensor(0.1002, grad_fn=<AbsBackward0>) False  my
# tensor(0.1036, grad_fn=<AbsBackward0>) False  my
# tensor(0.1025, grad_fn=<AbsBackward0>) False  my
# tensor(0.1002, grad_fn=<AbsBackward0>) False  my
# tensor(0.1003, grad_fn=<AbsBackward0>) False  my
# tensor(0.1006, grad_fn=<AbsBackward0>) False  my
# tensor(0.0983, grad_fn=<AbsBackward0>) False  my
# tensor(0.0973, grad_fn=<AbsBackward0>) False  my
# tensor(0.1004, grad_fn=<AbsBackward0>) False  my
# tensor(0.0972, grad_fn=<AbsBackward0>) False  my
# tensor(0.0965, grad_fn=<AbsBackward0>) False  my
# tensor(0.0970, grad_fn=<AbsBackward0>) False  my
# tensor(0.0962, grad_fn=<AbsBackward0>) False  my
# tensor(0.0958, grad_fn=<AbsBackward0>) False  my
# tensor(0.0940, grad_fn=<AbsBackward0>) False  my
# tensor(0.0941, grad_fn=<AbsBackward0>) False  my
# tensor(0.0943, grad_fn=<AbsBackward0>) False  my
# tensor(0.0938, grad_fn=<AbsBackward0>) False  my
# tensor(0.0956, grad_fn=<AbsBackward0>) False  my
# tensor(0.0935, grad_fn=<AbsBackward0>) False  my
# tensor(0.0930, grad_fn=<AbsBackward0>) False  my
# tensor(0.0956, grad_fn=<AbsBackward0>) False  my
# tensor(0.0948, grad_fn=<AbsBackward0>) False  my
# tensor(0.0909, grad_fn=<AbsBackward0>) False  my
# tensor(0.0934, grad_fn=<AbsBackward0>) False  my
# tensor(0.0915, grad_fn=<AbsBackward0>) False  my
# tensor(0.0885, grad_fn=<AbsBackward0>) False  my
# tensor(0.0893, grad_fn=<AbsBackward0>) False  my
# tensor(0.0877, grad_fn=<AbsBackward0>) False  my
# tensor(0.0898, grad_fn=<AbsBackward0>) False  my
# tensor(0.0882, grad_fn=<AbsBackward0>) False  my
# tensor(0.0878, grad_fn=<AbsBackward0>) False  my
# tensor(0.0878, grad_fn=<AbsBackward0>) False  my
# tensor(0.0896, grad_fn=<AbsBackward0>) False  my
# tensor(0.0842, grad_fn=<AbsBackward0>) False  my
# tensor(0.0880, grad_fn=<AbsBackward0>) False  my
# tensor(0.0837, grad_fn=<AbsBackward0>) False  my
# tensor(0.0843, grad_fn=<AbsBackward0>) False  my
# tensor(0.0829, grad_fn=<AbsBackward0>) False  my
# tensor(0.0845, grad_fn=<AbsBackward0>) False  my
# tensor(0.0854, grad_fn=<AbsBackward0>) False  my
# tensor(0.0841, grad_fn=<AbsBackward0>) False  my
# tensor(0.0825, grad_fn=<AbsBackward0>) False  my
# tensor(0.0908, grad_fn=<AbsBackward0>) False  my
# tensor(0.0863, grad_fn=<AbsBackward0>) False  my
# tensor(0.0899, grad_fn=<AbsBackward0>) False  my
# tensor(0.0838, grad_fn=<AbsBackward0>) False  my
# tensor(0.0874, grad_fn=<AbsBackward0>) False  my
# tensor(0.0829, grad_fn=<AbsBackward0>) False  my
# tensor(0.0857, grad_fn=<AbsBackward0>) False  my
# tensor(0.0809, grad_fn=<AbsBackward0>) False  my
# tensor(0.0821, grad_fn=<AbsBackward0>) False  my
# tensor(0.0822, grad_fn=<AbsBackward0>) False  my
# tensor(0.0820, grad_fn=<AbsBackward0>) False  my
# tensor(0.0808, grad_fn=<AbsBackward0>) False  my
# tensor(0.0815, grad_fn=<AbsBackward0>) False  my
# tensor(0.0801, grad_fn=<AbsBackward0>) False  my
# tensor(0.0777, grad_fn=<AbsBackward0>) False  my
# tensor(0.0820, grad_fn=<AbsBackward0>) False  my
# tensor(0.0809, grad_fn=<AbsBackward0>) False  my
# tensor(0.0795, grad_fn=<AbsBackward0>) False  my
# tensor(0.0787, grad_fn=<AbsBackward0>) False  my
# tensor(0.0758, grad_fn=<AbsBackward0>) False  my
# tensor(0.0810, grad_fn=<AbsBackward0>) False  my
# tensor(0.0791, grad_fn=<AbsBackward0>) False  my
# tensor(0.0751, grad_fn=<AbsBackward0>) False  my
# tensor(0.0773, grad_fn=<AbsBackward0>) False  my
# tensor(0.0762, grad_fn=<AbsBackward0>) False  my
# tensor(0.0767, grad_fn=<AbsBackward0>) False  my
# tensor(0.0778, grad_fn=<AbsBackward0>) False  my
# tensor(0.0773, grad_fn=<AbsBackward0>) False  my
# tensor(0.0799, grad_fn=<AbsBackward0>) False  my
# tensor(0.0805, grad_fn=<AbsBackward0>) False  my
# tensor(0.0751, grad_fn=<AbsBackward0>) False  my
# tensor(0.0815, grad_fn=<AbsBackward0>) False  my
# tensor(0.0760, grad_fn=<AbsBackward0>) False  my
# tensor(0.0798, grad_fn=<AbsBackward0>) False  my
# tensor(0.0730, grad_fn=<AbsBackward0>) False  my
# tensor(0.0830, grad_fn=<AbsBackward0>) False  my
# tensor(0.0738, grad_fn=<AbsBackward0>) False  my
# tensor(0.0753, grad_fn=<AbsBackward0>) False  my
# tensor(0.0788, grad_fn=<AbsBackward0>) False  my
# tensor(0.0737, grad_fn=<AbsBackward0>) False  my
# tensor(0.0802, grad_fn=<AbsBackward0>) False  my
# tensor(0.0729, grad_fn=<AbsBackward0>) False  my
# tensor(0.0774, grad_fn=<AbsBackward0>) False  my
# tensor(0.0736, grad_fn=<AbsBackward0>) False  my
# tensor(0.0735, grad_fn=<AbsBackward0>) False  my
# tensor(0.0778, grad_fn=<AbsBackward0>) False  my
# tensor(0.0704, grad_fn=<AbsBackward0>) False  my
# tensor(0.0811, grad_fn=<AbsBackward0>) False  my
# tensor(0.0701, grad_fn=<AbsBackward0>) False  my
# tensor(0.0784, grad_fn=<AbsBackward0>) False  my
# tensor(0.0707, grad_fn=<AbsBackward0>) False  my
# tensor(0.0731, grad_fn=<AbsBackward0>) False  my
# tensor(0.0721, grad_fn=<AbsBackward0>) False  my
# tensor(0.0715, grad_fn=<AbsBackward0>) False  my
# tensor(0.0693, grad_fn=<AbsBackward0>) False  my
# tensor(0.0693, grad_fn=<AbsBackward0>) False  my
# tensor(0.0730, grad_fn=<AbsBackward0>) False  my
# tensor(0.0705, grad_fn=<AbsBackward0>) False  my
# tensor(0.0718, grad_fn=<AbsBackward0>) False  my
# tensor(0.0669, grad_fn=<AbsBackward0>) False  my
# tensor(0.0709, grad_fn=<AbsBackward0>) False  my
# tensor(0.0692, grad_fn=<AbsBackward0>) False  my
# tensor(0.0682, grad_fn=<AbsBackward0>) False  my
# tensor(0.0678, grad_fn=<AbsBackward0>) False  my
# tensor(0.0723, grad_fn=<AbsBackward0>) False  my
# tensor(0.0680, grad_fn=<AbsBackward0>) False  my
# tensor(0.0681, grad_fn=<AbsBackward0>) False  my
# tensor(0.0684, grad_fn=<AbsBackward0>) False  my
# tensor(0.0652, grad_fn=<AbsBackward0>) False  my
# tensor(0.0671, grad_fn=<AbsBackward0>) False  my
# tensor(0.0657, grad_fn=<AbsBackward0>) False  my
# tensor(0.0639, grad_fn=<AbsBackward0>) False  my
# tensor(0.0669, grad_fn=<AbsBackward0>) False  my
# tensor(0.0637, grad_fn=<AbsBackward0>) False  my
# tensor(0.0663, grad_fn=<AbsBackward0>) False  my
# tensor(0.0666, grad_fn=<AbsBackward0>) False  my
# tensor(0.0704, grad_fn=<AbsBackward0>) False  my
# tensor(0.0633, grad_fn=<AbsBackward0>) False  my
# tensor(0.0663, grad_fn=<AbsBackward0>) False  my
# tensor(0.0690, grad_fn=<AbsBackward0>) False  my
# tensor(0.0621, grad_fn=<AbsBackward0>) False  my
# tensor(0.0666, grad_fn=<AbsBackward0>) False  my
# tensor(0.0711, grad_fn=<AbsBackward0>) False  my
# tensor(0.0675, grad_fn=<AbsBackward0>) False  my
# tensor(0.0701, grad_fn=<AbsBackward0>) False  my
# tensor(0.0644, grad_fn=<AbsBackward0>) False  my
# tensor(0.0734, grad_fn=<AbsBackward0>) False  my
# tensor(0.0621, grad_fn=<AbsBackward0>) False  my
# tensor(0.0667, grad_fn=<AbsBackward0>) False  my
# tensor(0.0627, grad_fn=<AbsBackward0>) False  my
# tensor(0.0664, grad_fn=<AbsBackward0>) False  my
# tensor(0.0633, grad_fn=<AbsBackward0>) False  my
# tensor(0.0621, grad_fn=<AbsBackward0>) False  my
# tensor(0.0613, grad_fn=<AbsBackward0>) False  my
# tensor(0.0615, grad_fn=<AbsBackward0>) False  my
# tensor(0.0610, grad_fn=<AbsBackward0>) False  my
# tensor(0.0644, grad_fn=<AbsBackward0>) False  my
# tensor(0.0580, grad_fn=<AbsBackward0>) False  my
# tensor(0.0642, grad_fn=<AbsBackward0>) False  my
# tensor(0.0628, grad_fn=<AbsBackward0>) False  my
# tensor(0.0617, grad_fn=<AbsBackward0>) False  my
# tensor(0.0678, grad_fn=<AbsBackward0>) False  my
# tensor(0.0638, grad_fn=<AbsBackward0>) False  my
# tensor(0.0606, grad_fn=<AbsBackward0>) False  my
# tensor(0.0607, grad_fn=<AbsBackward0>) False  my
# tensor(0.0628, grad_fn=<AbsBackward0>) False  my
# tensor(0.0570, grad_fn=<AbsBackward0>) False  my
# tensor(0.0625, grad_fn=<AbsBackward0>) False  my
# tensor(0.0588, grad_fn=<AbsBackward0>) False  my
# tensor(0.0583, grad_fn=<AbsBackward0>) False  my
# tensor(0.0592, grad_fn=<AbsBackward0>) False  my
# tensor(0.0565, grad_fn=<AbsBackward0>) False  my
# tensor(0.0573, grad_fn=<AbsBackward0>) False  my
# tensor(0.0574, grad_fn=<AbsBackward0>) False  my
# tensor(0.0544, grad_fn=<AbsBackward0>) False  my
# tensor(0.0584, grad_fn=<AbsBackward0>) False  my
# tensor(0.0544, grad_fn=<AbsBackward0>) False  my
# tensor(0.0572, grad_fn=<AbsBackward0>) False  my
# tensor(0.0629, grad_fn=<AbsBackward0>) False  my
# tensor(0.0574, grad_fn=<AbsBackward0>) False  my
# tensor(0.0627, grad_fn=<AbsBackward0>) False  my
# tensor(0.0563, grad_fn=<AbsBackward0>) False  my
# tensor(0.0577, grad_fn=<AbsBackward0>) False  my
# tensor(0.0548, grad_fn=<AbsBackward0>) False  my
# tensor(0.0601, grad_fn=<AbsBackward0>) False  my
# tensor(0.0554, grad_fn=<AbsBackward0>) False  my
# tensor(0.0516, grad_fn=<AbsBackward0>) False  my
# tensor(0.0610, grad_fn=<AbsBackward0>) False  my
# tensor(0.0554, grad_fn=<AbsBackward0>) False  my
# tensor(0.0568, grad_fn=<AbsBackward0>) False  my
# tensor(0.0646, grad_fn=<AbsBackward0>) False  my
# tensor(0.0568, grad_fn=<AbsBackward0>) False  my
# tensor(0.0630, grad_fn=<AbsBackward0>) False  my
# tensor(0.0568, grad_fn=<AbsBackward0>) False  my
# tensor(0.0577, grad_fn=<AbsBackward0>) False  my
# tensor(0.0549, grad_fn=<AbsBackward0>) False  my
# tensor(0.0602, grad_fn=<AbsBackward0>) False  my
# tensor(0.0558, grad_fn=<AbsBackward0>) False  my
# tensor(0.0571, grad_fn=<AbsBackward0>) False  my
# tensor(0.0528, grad_fn=<AbsBackward0>) False  my
# tensor(0.0546, grad_fn=<AbsBackward0>) False  my
# tensor(0.0539, grad_fn=<AbsBackward0>) False  my
# tensor(0.0573, grad_fn=<AbsBackward0>) False  my
# tensor(0.0525, grad_fn=<AbsBackward0>) False  my
# tensor(0.0525, grad_fn=<AbsBackward0>) False  my
# tensor(0.0560, grad_fn=<AbsBackward0>) False  my
# tensor(0.0502, grad_fn=<AbsBackward0>) False  my
# tensor(0.0528, grad_fn=<AbsBackward0>) False  my
# tensor(0.0557, grad_fn=<AbsBackward0>) False  my
# tensor(0.0505, grad_fn=<AbsBackward0>) False  my
# tensor(0.0552, grad_fn=<AbsBackward0>) False  my
# tensor(0.0531, grad_fn=<AbsBackward0>) False  my
# tensor(0.0506, grad_fn=<AbsBackward0>) False  my
# tensor(0.0501, grad_fn=<AbsBackward0>) False  my
# tensor(0.0533, grad_fn=<AbsBackward0>) False  my
# tensor(0.0484, grad_fn=<AbsBackward0>) False  my
# tensor(0.0512, grad_fn=<AbsBackward0>) False  my
# tensor(0.0519, grad_fn=<AbsBackward0>) False  my
# tensor(0.0518, grad_fn=<AbsBackward0>) False  my
# tensor(0.0483, grad_fn=<AbsBackward0>) False  my
# tensor(0.0477, grad_fn=<AbsBackward0>) False  my
# tensor(0.0494, grad_fn=<AbsBackward0>) False  my
# tensor(0.0464, grad_fn=<AbsBackward0>) False  my
# tensor(0.0505, grad_fn=<AbsBackward0>) False  my
# tensor(0.0478, grad_fn=<AbsBackward0>) False  my
# tensor(0.0495, grad_fn=<AbsBackward0>) False  my
# tensor(0.0511, grad_fn=<AbsBackward0>) False  my
# tensor(0.0488, grad_fn=<AbsBackward0>) False  my
# tensor(0.0466, grad_fn=<AbsBackward0>) False  my
# tensor(0.0483, grad_fn=<AbsBackward0>) False  my
# tensor(0.0461, grad_fn=<AbsBackward0>) False  my
# tensor(0.0462, grad_fn=<AbsBackward0>) False  my
# tensor(0.0451, grad_fn=<AbsBackward0>) False  my
# tensor(0.0487, grad_fn=<AbsBackward0>) False  my
# tensor(0.0459, grad_fn=<AbsBackward0>) False  my
# tensor(0.0436, grad_fn=<AbsBackward0>) False  my
# tensor(0.0437, grad_fn=<AbsBackward0>) False  my
# tensor(0.0460, grad_fn=<AbsBackward0>) False  my
# tensor(0.0453, grad_fn=<AbsBackward0>) False  my
# tensor(0.0458, grad_fn=<AbsBackward0>) False  my
# tensor(0.0435, grad_fn=<AbsBackward0>) False  my
# tensor(0.0422, grad_fn=<AbsBackward0>) False  my
# tensor(0.0461, grad_fn=<AbsBackward0>) False  my
# tensor(0.0429, grad_fn=<AbsBackward0>) False  my
# tensor(0.0468, grad_fn=<AbsBackward0>) False  my
# tensor(0.0461, grad_fn=<AbsBackward0>) False  my
# tensor(0.0437, grad_fn=<AbsBackward0>) False  my
# tensor(0.0427, grad_fn=<AbsBackward0>) False  my
# tensor(0.0470, grad_fn=<AbsBackward0>) False  my
# tensor(0.0457, grad_fn=<AbsBackward0>) False  my
# tensor(0.0492, grad_fn=<AbsBackward0>) False  my
# tensor(0.0441, grad_fn=<AbsBackward0>) False  my
# tensor(0.0439, grad_fn=<AbsBackward0>) False  my
# tensor(0.0490, grad_fn=<AbsBackward0>) False  my
# tensor(0.0412, grad_fn=<AbsBackward0>) False  my
# tensor(0.0467, grad_fn=<AbsBackward0>) False  my
# tensor(0.0464, grad_fn=<AbsBackward0>) False  my
# tensor(0.0427, grad_fn=<AbsBackward0>) False  my
# tensor(0.0436, grad_fn=<AbsBackward0>) False  my
# tensor(0.0408, grad_fn=<AbsBackward0>) False  my
# tensor(0.0464, grad_fn=<AbsBackward0>) False  my
# tensor(0.0397, grad_fn=<AbsBackward0>) False  my
# tensor(0.0418, grad_fn=<AbsBackward0>) False  my
# tensor(0.0453, grad_fn=<AbsBackward0>) False  my
# tensor(0.0431, grad_fn=<AbsBackward0>) False  my
# tensor(0.0409, grad_fn=<AbsBackward0>) False  my
# tensor(0.0383, grad_fn=<AbsBackward0>) False  my
# tensor(0.0464, grad_fn=<AbsBackward0>) False  my
# tensor(0.0389, grad_fn=<AbsBackward0>) False  my
# tensor(0.0421, grad_fn=<AbsBackward0>) False  my
# tensor(0.0395, grad_fn=<AbsBackward0>) False  my
# tensor(0.0435, grad_fn=<AbsBackward0>) False  my
# tensor(0.0443, grad_fn=<AbsBackward0>) False  my
# tensor(0.0434, grad_fn=<AbsBackward0>) False  my
# tensor(0.0441, grad_fn=<AbsBackward0>) False  my
# tensor(0.0429, grad_fn=<AbsBackward0>) False  my
# tensor(0.0428, grad_fn=<AbsBackward0>) False  my
# tensor(0.0460, grad_fn=<AbsBackward0>) False  my
# tensor(0.0446, grad_fn=<AbsBackward0>) False  my
# tensor(0.0395, grad_fn=<AbsBackward0>) False  my
# tensor(0.0448, grad_fn=<AbsBackward0>) False  my
# tensor(0.0405, grad_fn=<AbsBackward0>) False  my
# tensor(0.0381, grad_fn=<AbsBackward0>) False  my
# tensor(0.0399, grad_fn=<AbsBackward0>) False  my
# tensor(0.0389, grad_fn=<AbsBackward0>) False  my
# tensor(0.0424, grad_fn=<AbsBackward0>) False  my
# tensor(0.0377, grad_fn=<AbsBackward0>) False  my
# tensor(0.0440, grad_fn=<AbsBackward0>) False  my
# tensor(0.0388, grad_fn=<AbsBackward0>) False  my
# tensor(0.0388, grad_fn=<AbsBackward0>) False  my
# tensor(0.0473, grad_fn=<AbsBackward0>) False  my
# tensor(0.0379, grad_fn=<AbsBackward0>) False  my
# tensor(0.0473, grad_fn=<AbsBackward0>) False  my
# tensor(0.0426, grad_fn=<AbsBackward0>) False  my
# tensor(0.0381, grad_fn=<AbsBackward0>) False  my
# tensor(0.0482, grad_fn=<AbsBackward0>) False  my
# tensor(0.0390, grad_fn=<AbsBackward0>) False  my
# tensor(0.0435, grad_fn=<AbsBackward0>) False  my
# tensor(0.0407, grad_fn=<AbsBackward0>) False  my
# tensor(0.0406, grad_fn=<AbsBackward0>) False  my
# tensor(0.0379, grad_fn=<AbsBackward0>) False  my
# tensor(0.0398, grad_fn=<AbsBackward0>) False  my
# tensor(0.0379, grad_fn=<AbsBackward0>) False  my
# tensor(0.0428, grad_fn=<AbsBackward0>) False  my
# tensor(0.0392, grad_fn=<AbsBackward0>) False  my
# tensor(0.0426, grad_fn=<AbsBackward0>) False  my
# tensor(0.0379, grad_fn=<AbsBackward0>) False  my
# tensor(0.0397, grad_fn=<AbsBackward0>) False  my
# tensor(0.0390, grad_fn=<AbsBackward0>) False  my
# tensor(0.0396, grad_fn=<AbsBackward0>) False  my
# tensor(0.0407, grad_fn=<AbsBackward0>) False  my
# tensor(0.0451, grad_fn=<AbsBackward0>) False  my
# tensor(0.0399, grad_fn=<AbsBackward0>) False  my
# tensor(0.0409, grad_fn=<AbsBackward0>) False  my
# tensor(0.0430, grad_fn=<AbsBackward0>) False  my
# tensor(0.0378, grad_fn=<AbsBackward0>) False  my
# tensor(0.0413, grad_fn=<AbsBackward0>) False  my
# tensor(0.0383, grad_fn=<AbsBackward0>) False  my
# tensor(0.0367, grad_fn=<AbsBackward0>) False  my
# tensor(0.0387, grad_fn=<AbsBackward0>) False  my
# tensor(0.0417, grad_fn=<AbsBackward0>) False  my
# tensor(0.0343, grad_fn=<AbsBackward0>) False  my
# tensor(0.0382, grad_fn=<AbsBackward0>) False  my
# tensor(0.0383, grad_fn=<AbsBackward0>) False  my
# tensor(0.0329, grad_fn=<AbsBackward0>) False  my
# tensor(0.0368, grad_fn=<AbsBackward0>) False  my
# tensor(0.0343, grad_fn=<AbsBackward0>) False  my
# tensor(0.0342, grad_fn=<AbsBackward0>) False  my
# tensor(0.0364, grad_fn=<AbsBackward0>) False  my
# tensor(0.0307, grad_fn=<AbsBackward0>) False  my
# tensor(0.0341, grad_fn=<AbsBackward0>) False  my
# tensor(0.0341, grad_fn=<AbsBackward0>) False  my
# tensor(0.0380, grad_fn=<AbsBackward0>) False  my
# tensor(0.0329, grad_fn=<AbsBackward0>) False  my
# tensor(0.0365, grad_fn=<AbsBackward0>) False  my
# tensor(0.0330, grad_fn=<AbsBackward0>) False  my
# tensor(0.0342, grad_fn=<AbsBackward0>) False  my
# tensor(0.0347, grad_fn=<AbsBackward0>) False  my
# tensor(0.0311, grad_fn=<AbsBackward0>) False  my
# tensor(0.0392, grad_fn=<AbsBackward0>) False  my
# tensor(0.0332, grad_fn=<AbsBackward0>) False  my
# tensor(0.0359, grad_fn=<AbsBackward0>) False  my
# tensor(0.0314, grad_fn=<AbsBackward0>) False  my
# tensor(0.0348, grad_fn=<AbsBackward0>) False  my
# tensor(0.0331, grad_fn=<AbsBackward0>) False  my
# tensor(0.0322, grad_fn=<AbsBackward0>) False  my
# tensor(0.0339, grad_fn=<AbsBackward0>) False  my
# tensor(0.0338, grad_fn=<AbsBackward0>) False  my
# tensor(0.0386, grad_fn=<AbsBackward0>) False  my
# tensor(0.0309, grad_fn=<AbsBackward0>) False  my
# tensor(0.0427, grad_fn=<AbsBackward0>) False  my
# tensor(0.0324, grad_fn=<AbsBackward0>) False  my
# tensor(0.0372, grad_fn=<AbsBackward0>) False  my
# tensor(0.0347, grad_fn=<AbsBackward0>) False  my
# tensor(0.0341, grad_fn=<AbsBackward0>) False  my
# tensor(0.0372, grad_fn=<AbsBackward0>) False  my
# tensor(0.0320, grad_fn=<AbsBackward0>) False  my
# tensor(0.0392, grad_fn=<AbsBackward0>) False  my
# tensor(0.0347, grad_fn=<AbsBackward0>) False  my
# tensor(0.0383, grad_fn=<AbsBackward0>) False  my
# tensor(0.0406, grad_fn=<AbsBackward0>) False  my
# tensor(0.0331, grad_fn=<AbsBackward0>) False  my
# tensor(0.0359, grad_fn=<AbsBackward0>) False  my
# tensor(0.0339, grad_fn=<AbsBackward0>) False  my
# tensor(0.0330, grad_fn=<AbsBackward0>) False  my
# tensor(0.0360, grad_fn=<AbsBackward0>) False  my
# tensor(0.0314, grad_fn=<AbsBackward0>) False  my
# tensor(0.0346, grad_fn=<AbsBackward0>) False  my
# tensor(0.0329, grad_fn=<AbsBackward0>) False  my
# tensor(0.0355, grad_fn=<AbsBackward0>) False  my
# tensor(0.0325, grad_fn=<AbsBackward0>) False  my
# tensor(0.0290, grad_fn=<AbsBackward0>) False  my
# tensor(0.0366, grad_fn=<AbsBackward0>) False  my
# tensor(0.0288, grad_fn=<AbsBackward0>) False  my
# tensor(0.0335, grad_fn=<AbsBackward0>) False  my
# tensor(0.0320, grad_fn=<AbsBackward0>) False  my
# tensor(0.0287, grad_fn=<AbsBackward0>) False  my
# tensor(0.0313, grad_fn=<AbsBackward0>) False  my
# tensor(0.0283, grad_fn=<AbsBackward0>) False  my
# tensor(0.0291, grad_fn=<AbsBackward0>) False  my
# tensor(0.0273, grad_fn=<AbsBackward0>) False  my
# tensor(0.0275, grad_fn=<AbsBackward0>) False  my
# tensor(0.0290, grad_fn=<AbsBackward0>) False  my
# tensor(0.0301, grad_fn=<AbsBackward0>) False  my
# tensor(0.0283, grad_fn=<AbsBackward0>) False  my
# tensor(0.0263, grad_fn=<AbsBackward0>) False  my
# tensor(0.0268, grad_fn=<AbsBackward0>) False  my
# tensor(0.0303, grad_fn=<AbsBackward0>) False  my
# tensor(0.0294, grad_fn=<AbsBackward0>) False  my
# tensor(0.0247, grad_fn=<AbsBackward0>) False  my
# tensor(0.0319, grad_fn=<AbsBackward0>) False  my
# tensor(0.0290, grad_fn=<AbsBackward0>) False  my
# tensor(0.0267, grad_fn=<AbsBackward0>) False  my
# tensor(0.0259, grad_fn=<AbsBackward0>) False  my
# tensor(0.0297, grad_fn=<AbsBackward0>) False  my
# tensor(0.0241, grad_fn=<AbsBackward0>) False  my
# tensor(0.0253, grad_fn=<AbsBackward0>) False  my
# tensor(0.0280, grad_fn=<AbsBackward0>) False  my
# tensor(0.0237, grad_fn=<AbsBackward0>) False  my
# tensor(0.0264, grad_fn=<AbsBackward0>) False  my
# tensor(0.0275, grad_fn=<AbsBackward0>) False  my
# tensor(0.0245, grad_fn=<AbsBackward0>) False  my
# tensor(0.0224, grad_fn=<AbsBackward0>) False  my
# tensor(0.0274, grad_fn=<AbsBackward0>) False  my
# tensor(0.0257, grad_fn=<AbsBackward0>) False  my
# tensor(0.0237, grad_fn=<AbsBackward0>) False  my
# tensor(0.0259, grad_fn=<AbsBackward0>) False  my
# tensor(0.0238, grad_fn=<AbsBackward0>) False  my
# tensor(0.0270, grad_fn=<AbsBackward0>) False  my
# tensor(0.0235, grad_fn=<AbsBackward0>) False  my
# tensor(0.0283, grad_fn=<AbsBackward0>) False  my
# tensor(0.0265, grad_fn=<AbsBackward0>) False  my
# tensor(0.0228, grad_fn=<AbsBackward0>) False  my
# tensor(0.0277, grad_fn=<AbsBackward0>) False  my
# tensor(0.0270, grad_fn=<AbsBackward0>) False  my
# tensor(0.0256, grad_fn=<AbsBackward0>) False  my
# tensor(0.0269, grad_fn=<AbsBackward0>) False  my
# tensor(0.0255, grad_fn=<AbsBackward0>) False  my
# tensor(0.0302, grad_fn=<AbsBackward0>) False  my
# tensor(0.0309, grad_fn=<AbsBackward0>) False  my
# tensor(0.0252, grad_fn=<AbsBackward0>) False  my
# tensor(0.0331, grad_fn=<AbsBackward0>) False  my
# tensor(0.0229, grad_fn=<AbsBackward0>) False  my
# tensor(0.0270, grad_fn=<AbsBackward0>) False  my
# tensor(0.0280, grad_fn=<AbsBackward0>) False  my
# tensor(0.0271, grad_fn=<AbsBackward0>) False  my
# tensor(0.0274, grad_fn=<AbsBackward0>) False  my
# tensor(0.0291, grad_fn=<AbsBackward0>) False  my
# tensor(0.0301, grad_fn=<AbsBackward0>) False  my
# tensor(0.0268, grad_fn=<AbsBackward0>) False  my
# tensor(0.0292, grad_fn=<AbsBackward0>) False  my
# tensor(0.0263, grad_fn=<AbsBackward0>) False  my
# tensor(0.0231, grad_fn=<AbsBackward0>) False  my
# tensor(0.0285, grad_fn=<AbsBackward0>) False  my
# tensor(0.0250, grad_fn=<AbsBackward0>) False  my
# tensor(0.0229, grad_fn=<AbsBackward0>) False  my
# tensor(0.0255, grad_fn=<AbsBackward0>) False  my
# tensor(0.0217, grad_fn=<AbsBackward0>) False  my
# tensor(0.0201, grad_fn=<AbsBackward0>) False  my
# tensor(0.0237, grad_fn=<AbsBackward0>) False  my
# tensor(0.0199, grad_fn=<AbsBackward0>) False  my
# tensor(0.0227, grad_fn=<AbsBackward0>) False  my
# tensor(0.0210, grad_fn=<AbsBackward0>) False  my
# tensor(0.0213, grad_fn=<AbsBackward0>) False  my
# tensor(0.0195, grad_fn=<AbsBackward0>) False  my
# tensor(0.0202, grad_fn=<AbsBackward0>) False  my
# tensor(0.0205, grad_fn=<AbsBackward0>) False  my
# tensor(0.0209, grad_fn=<AbsBackward0>) False  my
# tensor(0.0194, grad_fn=<AbsBackward0>) False  my
# tensor(0.0214, grad_fn=<AbsBackward0>) False  my
# tensor(0.0186, grad_fn=<AbsBackward0>) False  my
# tensor(0.0222, grad_fn=<AbsBackward0>) False  my
# tensor(0.0237, grad_fn=<AbsBackward0>) False  my
# tensor(0.0189, grad_fn=<AbsBackward0>) False  my
# tensor(0.0247, grad_fn=<AbsBackward0>) False  my
# tensor(0.0177, grad_fn=<AbsBackward0>) False  my
# tensor(0.0281, grad_fn=<AbsBackward0>) False  my
# tensor(0.0232, grad_fn=<AbsBackward0>) False  my
# tensor(0.0219, grad_fn=<AbsBackward0>) False  my
# tensor(0.0226, grad_fn=<AbsBackward0>) False  my
# tensor(0.0219, grad_fn=<AbsBackward0>) False  my
# tensor(0.0238, grad_fn=<AbsBackward0>) False  my
# tensor(0.0173, grad_fn=<AbsBackward0>) False  my
# tensor(0.0201, grad_fn=<AbsBackward0>) False  my
# tensor(0.0203, grad_fn=<AbsBackward0>) False  my
# tensor(0.0194, grad_fn=<AbsBackward0>) False  my
# tensor(0.0204, grad_fn=<AbsBackward0>) False  my
# tensor(0.0192, grad_fn=<AbsBackward0>) False  my
# tensor(0.0208, grad_fn=<AbsBackward0>) False  my
# tensor(0.0175, grad_fn=<AbsBackward0>) False  my
# tensor(0.0202, grad_fn=<AbsBackward0>) False  my
# tensor(0.0222, grad_fn=<AbsBackward0>) False  my
# tensor(0.0184, grad_fn=<AbsBackward0>) False  my
# tensor(0.0228, grad_fn=<AbsBackward0>) False  my
# tensor(0.0189, grad_fn=<AbsBackward0>) False  my
# tensor(0.0245, grad_fn=<AbsBackward0>) False  my
# tensor(0.0205, grad_fn=<AbsBackward0>) False  my
# tensor(0.0204, grad_fn=<AbsBackward0>) False  my
# tensor(0.0242, grad_fn=<AbsBackward0>) False  my
# tensor(0.0193, grad_fn=<AbsBackward0>) False  my
# tensor(0.0195, grad_fn=<AbsBackward0>) False  my
# tensor(0.0215, grad_fn=<AbsBackward0>) False  my
# tensor(0.0152, grad_fn=<AbsBackward0>) False  my
# tensor(0.0182, grad_fn=<AbsBackward0>) False  my
# tensor(0.0176, grad_fn=<AbsBackward0>) False  my
# tensor(0.0188, grad_fn=<AbsBackward0>) False  my
# tensor(0.0208, grad_fn=<AbsBackward0>) False  my
# tensor(0.0230, grad_fn=<AbsBackward0>) False  my
# tensor(0.0181, grad_fn=<AbsBackward0>) False  my
# tensor(0.0255, grad_fn=<AbsBackward0>) False  my
# tensor(0.0200, grad_fn=<AbsBackward0>) False  my
# tensor(0.0179, grad_fn=<AbsBackward0>) False  my
# tensor(0.0240, grad_fn=<AbsBackward0>) False  my
# tensor(0.0199, grad_fn=<AbsBackward0>) False  my
# tensor(0.0190, grad_fn=<AbsBackward0>) False  my
# tensor(0.0238, grad_fn=<AbsBackward0>) False  my
# tensor(0.0173, grad_fn=<AbsBackward0>) False  my
# tensor(0.0175, grad_fn=<AbsBackward0>) False  my
# tensor(0.0188, grad_fn=<AbsBackward0>) False  my
# tensor(0.0158, grad_fn=<AbsBackward0>) False  my
# tensor(0.0225, grad_fn=<AbsBackward0>) False  my
# tensor(0.0174, grad_fn=<AbsBackward0>) False  my
# tensor(0.0214, grad_fn=<AbsBackward0>) False  my
# tensor(0.0212, grad_fn=<AbsBackward0>) False  my
# tensor(0.0173, grad_fn=<AbsBackward0>) False  my
# tensor(0.0180, grad_fn=<AbsBackward0>) False  my
# tensor(0.0183, grad_fn=<AbsBackward0>) False  my
# tensor(0.0151, grad_fn=<AbsBackward0>) False  my
# tensor(0.0193, grad_fn=<AbsBackward0>) False  my
# tensor(0.0165, grad_fn=<AbsBackward0>) False  my
# tensor(0.0205, grad_fn=<AbsBackward0>) False  my
# tensor(0.0167, grad_fn=<AbsBackward0>) False  my
# tensor(0.0151, grad_fn=<AbsBackward0>) False  my
# tensor(0.0151, grad_fn=<AbsBackward0>) False  my
# tensor(0.0156, grad_fn=<AbsBackward0>) False  my
# tensor(0.0160, grad_fn=<AbsBackward0>) False  my
# tensor(0.0169, grad_fn=<AbsBackward0>) False  my
# tensor(0.0141, grad_fn=<AbsBackward0>) False  my
# tensor(0.0111, grad_fn=<AbsBackward0>) False  my
# tensor(0.0125, grad_fn=<AbsBackward0>) False  my
# tensor(0.0148, grad_fn=<AbsBackward0>) False  my
# tensor(0.0139, grad_fn=<AbsBackward0>) False  my
# tensor(0.0154, grad_fn=<AbsBackward0>) False  my
# tensor(0.0112, grad_fn=<AbsBackward0>) False  my
# tensor(0.0113, grad_fn=<AbsBackward0>) False  my
# tensor(0.0168, grad_fn=<AbsBackward0>) False  my
# tensor(0.0111, grad_fn=<AbsBackward0>) False  my
# tensor(0.0190, grad_fn=<AbsBackward0>) False  my
# tensor(0.0126, grad_fn=<AbsBackward0>) False  my
# tensor(0.0159, grad_fn=<AbsBackward0>) False  my
# tensor(0.0104, grad_fn=<AbsBackward0>) False  my
# tensor(0.0157, grad_fn=<AbsBackward0>) False  my
# tensor(0.0105, grad_fn=<AbsBackward0>) False  my
# tensor(0.0165, grad_fn=<AbsBackward0>) False  my
# tensor(0.0143, grad_fn=<AbsBackward0>) False  my
# tensor(0.0174, grad_fn=<AbsBackward0>) False  my
# tensor(0.0126, grad_fn=<AbsBackward0>) False  my
# tensor(0.0200, grad_fn=<AbsBackward0>) False  my
# tensor(0.0161, grad_fn=<AbsBackward0>) False  my
# tensor(0.0154, grad_fn=<AbsBackward0>) False  my
# tensor(0.0189, grad_fn=<AbsBackward0>) False  my
# tensor(0.0157, grad_fn=<AbsBackward0>) False  my
# tensor(0.0158, grad_fn=<AbsBackward0>) False  my
# tensor(0.0129, grad_fn=<AbsBackward0>) False  my
# tensor(0.0220, grad_fn=<AbsBackward0>) False  my
# tensor(0.0141, grad_fn=<AbsBackward0>) False  my
# tensor(0.0182, grad_fn=<AbsBackward0>) False  my
# tensor(0.0179, grad_fn=<AbsBackward0>) False  my
# tensor(0.0130, grad_fn=<AbsBackward0>) False  my
# tensor(0.0159, grad_fn=<AbsBackward0>) False  my
# tensor(0.0170, grad_fn=<AbsBackward0>) False  my
# tensor(0.0130, grad_fn=<AbsBackward0>) False  my
# tensor(0.0156, grad_fn=<AbsBackward0>) False  my
# tensor(0.0139, grad_fn=<AbsBackward0>) False  my
# tensor(0.0119, grad_fn=<AbsBackward0>) False  my
# tensor(0.0146, grad_fn=<AbsBackward0>) False  my
# tensor(0.0128, grad_fn=<AbsBackward0>) False  my
# tensor(0.0160, grad_fn=<AbsBackward0>) False  my
# tensor(0.0135, grad_fn=<AbsBackward0>) False  my
# tensor(0.0148, grad_fn=<AbsBackward0>) False  my
# tensor(0.0135, grad_fn=<AbsBackward0>) False  my
# tensor(0.0132, grad_fn=<AbsBackward0>) False  my
# tensor(0.0120, grad_fn=<AbsBackward0>) False  my
# tensor(0.0132, grad_fn=<AbsBackward0>) False  my
# tensor(0.0102, grad_fn=<AbsBackward0>) False  my
# tensor(0.0131, grad_fn=<AbsBackward0>) False  my
# tensor(0.0107, grad_fn=<AbsBackward0>) False  my
# tensor(0.0112, grad_fn=<AbsBackward0>) False  my
# tensor(0.0107, grad_fn=<AbsBackward0>) False  my
# tensor(0.0085, grad_fn=<AbsBackward0>) False  my
# tensor(0.0110, grad_fn=<SubBackward0>) True  my
# tensor(0.0083, grad_fn=<SubBackward0>) True  my
